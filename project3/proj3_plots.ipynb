# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4]
all_resources_IPC = [.6948, .8480, .8663, .8691]
ialu_IPC = [.6948, .8287, .8417, .8418]
fpalu_IPC = [.6948, .6948, .6948, .6948]

# y_64 = [.240, .200, .151]
# y_128 = [.238, .184, .098]
# fig, ax = plt.subplots(figsize=(9,5))
# ax.set_ylabel('Miss Rate')
# ax.set_xlabel('Associativity')
# ax.set_title('64 set split vs 128 set unified cache performance')
# plt.plot(x, y_64, label='Effective Combined Cache Miss Rate')
# plt.plot(x, y_128, label='Unified Cache Miss Rate')
# plt.legend()
# fig.tight_layout()
# plt.show()

fig, ax = plt.subplots(figsize=(9,5))
ax.set_ylabel('IPC')
ax.set_xlabel('Number of resources')
ax.set_title('IPC vs resources performance')
plt.plot(x, all_resources_IPC, label='All Resources')
plt.plot(x, ialu_IPC, label='Integer ALUs')
plt.plot(x, fpalu_IPC, label='Floating Point ALUs')
plt.legend()
fig.tight_layout()
plt.show()
